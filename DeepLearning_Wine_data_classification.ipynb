# %%
#!pip install tensorflow==2.0

# %%
import tensorflow as tf
import pandas as pd      ##for csv
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
red = pd.read_csv("winequality-red.csv" , sep=";")
white = pd.read_csv("winequality-white.csv" , sep=";")

# %%
red
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
white
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
red.shape
# Out:
# (1599, 12)

# %%
white.shape
# Out:
# (4898, 12)

# %%
# concat 2 datasets and merge them
## first def class

red["Type"] = 1
white["Type"] = 0

# %%
##append the data in white from red and to ignore index for concatinating the dataset
wines = white.append(red, ignore_index=True)

# %%
wines.shape
# Out:
# (6497, 13)

# %%
wines
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0             0.270         0.36            20.7      0.045
# 1               6.3             0.300         0.34             1.6      0.049
# 2               8.1             0.280         0.40             6.9      0.050
# 3               7.2             0.230         0.32             8.5      0.058
# 4               7.2             0.230         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 6492            6.2             0.600         0.08             2.0      0.090
# 6493            5.9             0.550         0.10             2.2      0.062
# 6494            6.3             0.510         0.13             2.3      0.076
# 6495            5.9             0.645         0.12             2.0      0.075
# 6496            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
## split and shuffle data and apply StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

##cols independent and type dependent so diff datasets req
x,y = wines.iloc[:, :-1].values, wines.iloc[:, -1].values
trainX, testX, trainY, testY = train_test_split(x,y, test_size = 0.2, random_state = 12)

# %%
## convert data i.e scalardataset
scaller = StandardScaler()
trainX = scaller.fit_transform(trainX)
testX = scaller.fit_transform(testX)

# %% [markdown]
# # Deep Learning

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %%
trainX.shape
# Out:
# (5197, 12)

# %%
model = Sequential()    ##means object created from sequential class and we can store anything

# %%
model

# %%
## add layers based on input
model.add(Dense(30, activation = "relu", input_shape = (12, )))   ##input shape is trainX shape or independent columns
model.add(Dense(50, activation = "relu"))     ##to avoid underfit we add layers
model.add(Dense(1, activation = "sigmoid"))  ##sigmoid for probablity
model.compile(loss = "binary_crossentropy", optimizer="adam", metrics=["accuracy"])  ##building model done now compile ie loss and to compile loss we need binary_crossentropy
history = model.fit(trainX, trainY, validation_split = 0.3, epochs = 20, batch_size = trainX.shape[0])
##fir our model and store ie history and then validate data by validation split and then epochs is no.of times u execute/ iterate ur algo and batch size has neurons u want to pass ie trainX shape
# Out:
# Train on 3637 samples, validate on 1560 samples
# Epoch 1/20
# 3637/3637 [==============================] - 1s 256us/sample - loss: 0.6565 - accuracy: 0.5708 - val_loss: 0.6298 - val_accuracy: 0.6333
# Epoch 2/20
# 3637/3637 [==============================] - 0s 7us/sample - loss: 0.6377 - accuracy: 0.6057 - val_loss: 0.6116 - val_accuracy: 0.6814
# Epoch 3/20
# 3637/3637 [==============================] - 0s 6us/sample - loss: 0.6196 - accuracy: 0.6516 - val_loss: 0.5940 - val_accuracy: 0.7295
# Epoch 4/20
# 3637/3637 [==============================] - 0s 6us/sample - loss: 0.6020 - accuracy: 0.7055 - val_loss: 0.5769 - val_accuracy: 0.7891
# Epoch 5/20
# 3637/3637 [==============================] - 0s 8us/sample - loss: 0.5849 - accuracy: 0.7600 - val_loss: 0.5604 - val_accuracy: 0.8333
# Epoch 6/20
# 3637/3637 [==============================] - 0s 8us/sample - loss: 0.5685 - accuracy: 0.8051 - val_loss: 0.5444 - val_accuracy: 0.8609
# Epoch 7/20
# ...

# %%
model.summary()   ##check for layers   
## we have 12 inputs and 30 inputs ie 360 and every neuron has bias so 360+30
##on exectuing the n times it gives two times the layers present
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_12 (Dense)             (None, 30)                390
# _________________________________________________________________
# dense_13 (Dense)             (None, 50)                1550
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 51
# ...
# Total params: 1,991
# Trainable params: 1,991
# Non-trainable params: 0
# _________________________________________________________________

# %%
history.history
# Out:
# {'loss': [0.656517505645752,
#   0.6377358436584473,
#   0.6195611953735352,
#   0.6019657850265503,
#   0.5849372148513794,
#   0.5684728622436523,
#   0.5525485277175903,
#   0.5371479988098145,
#   0.5222439765930176,
#   0.5078117251396179,
#   0.49382925033569336,
#   0.48027053475379944,
#   0.4671083092689514,
#   0.4543244242668152,
#   0.44190147519111633,
#   0.4298108220100403,
#   0.41804003715515137,
#   0.40657177567481995,
#   0.39540597796440125,
#   0.3845272660255432],
#  'accuracy': [0.5708001,
#   0.605719,
#   0.65163594,
#   0.70552653,
#   0.759967,
#   0.80505913,
#   0.8364036,
#   0.8658235,
#   0.8823206,
#   0.8908441,
#   0.90019244,
#   0.90761614,
#   0.9131152,
#   0.9183393,
#   0.9227385,
#   0.925763,
#   0.92961234,
#   0.9331867,
#   0.9359362,
#   0.93841076],
#  'val_loss': [0.6297692656517029,
#   0.6115768551826477,
#   0.5939511656761169,
#   0.5768858790397644,
#   0.5603811144828796,
#   0.5444359183311462,
#   0.5290137529373169,
# ...

# %%
loss = history.history["loss"]
val_loss = history.history["val_loss"]
accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]

# %%
tva = pd.DataFrame({              ##training validation accuracy
    "TrainingAcc":accuracy,
    "Val_Acc":val_accuracy
})

# %%
tva.boxplot()

# %%
## they are parallel

# %%
y_pred =np.round(model.predict(testX))

# %%
y_pred
# Out:
# array([[0.],
#        [0.],
#        [0.],
#        ...,
#        [0.],
#        [1.],
#        [0.]], dtype=float32)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(testY, y_pred)
# Out:
# 0.9415384615384615

# %%
model.save("14.1_wine_model.h5")

# %%
from tensorflow.keras.models import load_model

# %%
New_Model = load_model("14.1_wine_model.h5")

# %%
np.round = (New_Model.predict(testX))
